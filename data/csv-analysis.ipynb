# %% [markdown]
# CSV Analysis of Data Relationships Before Making A Database Diagram

# %%
import pandas as pd
import numpy as np

# %%
# read in 6 .csv files
dept = pd.read_csv('departments.csv')
emp = pd.read_csv('dept_emp.csv')
man = pd.read_csv('dept_manager.csv')
info = pd.read_csv('employees.csv')
salary = pd.read_csv('salaries.csv')
title = pd.read_csv('titles.csv')

# %% [markdown]
# Departments

# %%
# display department data frame
dept.head()
# Out:
#   dept_no        dept_name
# 0    d001        Marketing
# 1    d002          Finance
# 2    d003  Human Resources
# 3    d004       Production
# 4    d005      Development

# %% [markdown]
# Departments of Employees

# %%
# display employee dept data frame
emp['emp_no'][331539]
# Out:
# 499942

# %%
# calculate unique employees and length of series
emp['emp_no'].nunique(), len(emp['emp_no'])
# Out:
# (300024, 331603)

# %%
# find duplicates to confirm 1 to many relationship
emp['duplicates'] = emp['emp_no'].duplicated(keep=False)
emp.head(15)
# Out:
#     emp_no dept_no   from_date     to_date  duplicates
# 0    10001    d005  1986-06-26  9999-01-01       False
# 1    10002    d007  1996-08-03  9999-01-01       False
# 2    10003    d004  1995-12-03  9999-01-01       False
# 3    10004    d004  1986-12-01  9999-01-01       False
# 4    10005    d003  1989-09-12  9999-01-01       False
# 5    10006    d005  1990-08-05  9999-01-01       False
# 6    10007    d008  1989-02-10  9999-01-01       False
# 7    10008    d005  1998-03-11  2000-07-31       False
# 8    10009    d006  1985-02-18  9999-01-01       False
# 9    10010    d004  1996-11-24  2000-06-26        True
# 10   10010    d006  2000-06-26  9999-01-01        True
# 11   10011    d009  1990-01-22  1996-11-09       False
# 12   10012    d005  1992-12-18  9999-01-01       False
# 13   10013    d003  1985-10-20  9999-01-01       False
# 14   10014    d005  1993-12-29  9999-01-01       False

# %% [markdown]
# Departments of Managers

# %%
# display manager data frame
man
# Out:
#    dept_no  emp_no   from_date     to_date
# 0     d001  110022  1985-01-01  1991-10-01
# 1     d001  110039  1991-10-01  9999-01-01
# 2     d002  110085  1985-01-01  1989-12-17
# 3     d002  110114  1989-12-17  9999-01-01
# 4     d003  110183  1985-01-01  1992-03-21
# 5     d003  110228  1992-03-21  9999-01-01
# 6     d004  110303  1985-01-01  1988-09-09
# 7     d004  110344  1988-09-09  1992-08-02
# 8     d004  110386  1992-08-02  1996-08-30
# 9     d004  110420  1996-08-30  9999-01-01
# 10    d005  110511  1985-01-01  1992-04-25
# 11    d005  110567  1992-04-25  9999-01-01
# 12    d006  110725  1985-01-01  1989-05-06
# 13    d006  110765  1989-05-06  1991-09-12
# 14    d006  110800  1991-09-12  1994-06-28
# 15    d006  110854  1994-06-28  9999-01-01
# 16    d007  111035  1985-01-01  1991-03-07
# 17    d007  111133  1991-03-07  9999-01-01
# 18    d008  111400  1985-01-01  1991-04-08
# 19    d008  111534  1991-04-08  9999-01-01
# 20    d009  111692  1985-01-01  1988-10-17
# ...

# %%
# calculate unique managers and length of managers series
man['emp_no'].nunique(), len(man['emp_no'])
# Out:
# (24, 24)

# %%
# no duplicates
man['duplicates'] = man['emp_no'].duplicated(keep=False)
man
# Out:
#    dept_no  emp_no   from_date     to_date  duplicates
# 0     d001  110022  1985-01-01  1991-10-01       False
# 1     d001  110039  1991-10-01  9999-01-01       False
# 2     d002  110085  1985-01-01  1989-12-17       False
# 3     d002  110114  1989-12-17  9999-01-01       False
# 4     d003  110183  1985-01-01  1992-03-21       False
# 5     d003  110228  1992-03-21  9999-01-01       False
# 6     d004  110303  1985-01-01  1988-09-09       False
# 7     d004  110344  1988-09-09  1992-08-02       False
# 8     d004  110386  1992-08-02  1996-08-30       False
# 9     d004  110420  1996-08-30  9999-01-01       False
# 10    d005  110511  1985-01-01  1992-04-25       False
# 11    d005  110567  1992-04-25  9999-01-01       False
# 12    d006  110725  1985-01-01  1989-05-06       False
# 13    d006  110765  1989-05-06  1991-09-12       False
# 14    d006  110800  1991-09-12  1994-06-28       False
# 15    d006  110854  1994-06-28  9999-01-01       False
# ...

# %% [markdown]
# Employee Info

# %%
# display employee info data frame
info.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
# check if length of employees is the same as the employee data frame
len(info['emp_no'])
# Out:
# 300024

# %%
title['emp_no'][331400:331600]
# Out:
# 331400    424181
# 331401    424182
# 331402    424183
# 331403    424183
# 331404    424184
# 331405    424184
# 331406    424185
# 331407    424185
# 331408    424186
# 331409    424187
# 331410    424188
# 331411    424188
# 331412    424189
# 331413    424189
# 331414    424190
# 331415    424190
# 331416    424191
# 331417    424192
# 331418    424192
# 331419    424193
# 331420    424194
# 331421    424195
# 331422    424196
# 331423    424197
# 331424    424197
# 331425    424198
# 331426    424199
# 331427    424199
# 331428    424200
# 331429    424201
#            ...
# 331570    424300
# 331571    424300
# 331572    424301
# 331573    424302
# 331574    424302
# 331575    424303
# 331576    424304
# 331577    424304
# 331578    424305
# 331579    424305
# 331580    424306
# 331581    424306
# 331582    424306
# 331583    424307
# 331584    424308
# 331585    424309
# 331586    424309
# 331587    424310
# 331588    424310
# 331589    424311
# 331590    424312
# ...
